# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn # to get the California data set
import warnings 
import seaborn as sns


#species-1994.csv

# %%
df = endangered_animals_1994 = pd.read_csv("species-1994.csv")
df
# Out:
#     Lead Agency                     Scientific Name
# 0           FWS  Perognathus longimembris pacificus  \
# 1           FWS          Accipiter striatus venator
# 2           FWS       Buteo platypterus brunnescens
# 3           FWS               Anaxyrus californicus
# 4           FWS             Acipenser transmontanus
# ..          ...                                 ...
# 123         FWS                 Ctenitis squamigera
# 124         FWS                      Diellia erecta
# 125         FWS               Diplazium molokaiense
# 126         FWS                     Huperzia nutans
# 127         FWS                     Pteris lidgatei
#
#                                            Common Name
# 0                       Mouse, Pacific pocket (Entire)  \
# 1            Hawk, Puerto Rican sharp-shinned (Entire)
# 2             Hawk, Puerto Rican broad-winged (Entire)
# 3         Toad, arroyo (=arroyo southwestern) (Entire)
# 4    Sturgeon, white (U.S.A. (ID, MT), Canada (B.C....
# ...

# %%
df['Group'] = df['Group'].str.replace(r'<.*?>', '', regex=True)
df
# Out:
#     Lead Agency                     Scientific Name
# 0           FWS  Perognathus longimembris pacificus  \
# 1           FWS          Accipiter striatus venator
# 2           FWS       Buteo platypterus brunnescens
# 3           FWS               Anaxyrus californicus
# 4           FWS             Acipenser transmontanus
# ..          ...                                 ...
# 123         FWS                 Ctenitis squamigera
# 124         FWS                      Diellia erecta
# 125         FWS               Diplazium molokaiense
# 126         FWS                     Huperzia nutans
# 127         FWS                     Pteris lidgatei
#
#                                            Common Name
# 0                       Mouse, Pacific pocket (Entire)  \
# 1            Hawk, Puerto Rican sharp-shinned (Entire)
# 2             Hawk, Puerto Rican broad-winged (Entire)
# 3         Toad, arroyo (=arroyo southwestern) (Entire)
# 4    Sturgeon, white (U.S.A. (ID, MT), Canada (B.C....
# ...

# %%
sns.countplot(df,y="Group")
plt.figure(figsize=(30, 6))
