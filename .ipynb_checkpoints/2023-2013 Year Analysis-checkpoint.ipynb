# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# # YEARS LISTINGS

# %%
# importing years
data_2023 = pd.read_csv('CSVS/2023.csv')
data_2022 = pd.read_csv('CSVS/2022.csv')
data_2021 = pd.read_csv('CSVS/2021.csv')
data_2020 = pd.read_csv('CSVS/2020.csv')
data_2019 = pd.read_csv('CSVS/2019.csv')
data_2018 = pd.read_csv('CSVS/2018.csv')
data_2017 = pd.read_csv('CSVS/2017.csv')
data_2016 = pd.read_csv('CSVS/2016.csv')
data_2015 = pd.read_csv('CSVS/2015.csv')
data_2014 = pd.read_csv('CSVS/2014.csv')
data_2013 = pd.read_csv('CSVS/2013.csv')

# %%
# clean function for table 

def clean(table):
    table['Group'] = table['Group'].str.replace(r'<.*?>', '', regex=True)
    cleaned = table
    
    return cleaned

# %%
# APPLY CLEAN FUNCTION
df_2023 = clean(data_2023)
df_2022 = clean(data_2022)
df_2021 = clean(data_2021)
df_2020 = clean(data_2020)
df_2019 = clean(data_2019)
df_2018 = clean(data_2018)
df_2017 = clean(data_2017)
df_2016 = clean(data_2016)
df_2015 = clean(data_2015)
df_2014 = clean(data_2014)
df_2013 = clean(data_2013)

# %% [markdown]
# MERGE THE DATA

# %%
df_list = [df_2023,df_2022,df_2021,df_2020,df_2019,df_2018,df_2017,df_2016,df_2015,df_2014,df_2013]
df_joined = pd.concat(df_list, axis=0, ignore_index=True)

df_joined
# Out:
#     Lead Agency                  Scientific Name
# 0           FWS  Glaucidium brasilianum cactorum  \
# 1           FWS       Tympanuchus pallidicinctus
# 2           FWS       Tympanuchus pallidicinctus
# 3           FWS                      Rana boylii
# 4           FWS                      Rana boylii
# ..          ...                              ...
# 279         FWS               Schiedea salicaria
# 280         FWS           Sphaeralcea gierischii
# 281         FWS            Stenogyne cranwelliae
# 282         FWS           Stenogyne kauaulaensis
# 283         FWS              Wikstroemia villosa
#
#                                            Common Name
# 0       Pygmy-owl, cactus ferruginous (Wherever found)  \
# 1               Prairie-chicken, lesser (Northern DPS)
# 2               Prairie-chicken, lesser (Southern DPS)
# 3    Frog, foothill yellow-legged (Central Coast Di...
# 4    Frog, foothill yellow-legged (South Coast Dist...
# ..                                                 ...
# 279                                     No common name
# 280                                   mallow, Gierisch
# 281                                     No common name
# 282                                  No common name ()
# 283                                  No common name ()
#
#     Current\nESA Listing Status   Initial Listing Date             Group
# 0                      Threatened           2023/08/21             Birds
# 1                      Threatened           2023/03/27             Birds
# 2                      Endangered           2023/03/27             Birds
# 3                      Threatened           2023/09/28        Amphibians
# 4                      Endangered           2023/09/28        Amphibians
# ..                            ...                  ...               ...
# 279                    Endangered           2013/06/27  Flowering Plants
# 280                    Endangered           2013/09/12  Flowering Plants
# 281                    Endangered           2013/11/29  Flowering Plants
# 282                    Endangered           2013/06/27  Flowering Plants
# 283                    Endangered           2013/06/27  Flowering Plants
#
# [284 rows x 6 columns]

# %% [markdown]
# MOST ENDANGERED SPECIES

# %%
sns.countplot(df_joined,y="Group")
plt.figure(figsize=(30, 6))

# %% [markdown]
# # RELATIONSHIPS

# %% [markdown]
# Scientific Name vs LISTING STATUS by Group

# %%
sns.set(style="whitegrid")
g = sns.FacetGrid(df_joined, col="Group", col_wrap=4, height=4)
g.map(sns.countplot, 'Scientific Name', hue='Current\nESA Listing Status')
g.set_xticklabels(rotation=90)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:712: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 sns.set(style="whitegrid")
#       2 g = sns.FacetGrid(df_joined, col="Group", col_wrap=4, height=4)
# ----> 3 g.map(sns.countplot, 'Scientific Name', hue='Current\nESA Listing Status')
#       4 g.set_xticklabels(rotation=90)
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:752, in FacetGrid.map(self, func, *args, **kwargs)
#     749         plot_args = [v.values for v in plot_args]
#     751     # Draw the plot
# --> 752     self._facet_plot(func, ax, plot_args, kwargs)
#     754 # Finalize the annotations and layout
#     755 self._finalize_grid(args[:2])
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# --> 848 func(*plot_args, **plot_kwargs)
#     850 # Sort out the supporting information
#     851 self._update_legend_data(ax)
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Current
# ESA Listing Status'
